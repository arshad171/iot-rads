# %%
from data_generator import ImageDataGeneratorHandler
import numpy as np
import matplotlib.pyplot as plt

gen = ImageDataGeneratorHandler("../images-data1/",use_dynamic_mask=True)
e,i = gen.next()

# Plot the figure the model was trained on
plt.figure()
plt.set_cmap(plt.colormaps["gray"])
plt.imshow(i)

# Show the feature vector
print(f"Got a feature vector of dimensions {e.shape}")
print(e.transpose())
# Out:
# [[0.00798319]
#  [0.0314235 ]
#  [0.00931614]
#  [0.        ]
#  [0.04588809]
#  [0.        ]
#  [0.05610508]
#  [0.        ]
#  [0.        ]
#  [0.04482249]
#  [0.        ]
#  [0.00952471]
#  [0.01582741]
#  [0.        ]
#  [0.0047836 ]
#  [0.01627697]
#  [0.01751886]
#  [0.        ]
#  [0.        ]
#  [0.04571127]
#  [0.03863194]
#  [0.        ]
#  [0.        ]
#  [0.00121047]
#  [0.01863305]
#  [0.00567718]
#  [0.        ]
#  [0.        ]
#  [0.0009455 ]
#  [0.        ]
#  [0.01547451]
#  [0.        ]
#  [0.        ]
#  [0.04870969]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.04712874]
#  [0.02201971]
#  [0.02794984]
#  [0.02598584]
#  [0.02012553]
#  [0.        ]
#  [0.00029966]
#  [0.02843155]
#  [0.        ]
#  [0.        ]
#  [0.02092084]
#  [0.        ]
#  [0.00540028]
#  [0.        ]
#  [0.03701013]
#  [0.00354292]
#  [0.        ]
#  [0.0276741 ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.        ]
#  [0.02027589]
#  [0.        ]
# ...
